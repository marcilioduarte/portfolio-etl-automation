# %% [markdown]
# **O QUE ESSE CÓDIGO FAZ?**
#
# Dando seguimento ao código do ETL 1 da RAIS estabelecimentos, que faz o download, tratamento e importa os dados para o mongodb e para o postgresql no Dbeaver, esse código lê o dicionário que construímos da tabela (01_doc\dicionario_rais_estab_sebrae.xlsx) e importa as abas de dimensão pro MongoDB e para o PostgreSQL no Dbeaver.
#
# OBS: o código só precisará ser rodado novamente se houver mudança no layout da tabela (ex: acréscimo de colunas/categorias).

# %% [markdown]
# # **1. IMPORTANDO LIBS**

# %%
from datetime import date
import json
import pandas as pd
import pymongo as p
import psycopg2
#from psycopg2 import sql
#import requests
import urllib

# %% [markdown]
# # **2. EXECUTANDO**

# %% [markdown]
# ## **2.1 CRIANDO FUNÇÕES**

# %%
def load_config(file_path=r'..\..\config.json'):
    with open(file_path, 'r') as file:
        config = json.load(file)
    return config

# %%
# Função para fazer upload no mongodb seguindo o padrão das demais funções do tipo que já utilizamos

def upload_mongodb(df, arquivo):
    
    print("------- Conectando com o mongodb ------------------")     

    config = load_config()

    host = config["mongodb"]["host"]
    port = config["mongodb"]["port"]
    user_name = config["mongodb"]["user_name"]
    password = config["mongodb"]["password"]
    db_name = config["mongodb"]["db_name"]
    
    client = p.MongoClient(f"mongodb://{user_name}:{urllib.parse.quote_plus(password)}@{host}:{port}/{db_name}")
    db = client.SEBRAE
    type(client)

    print(client.list_database_names())
    print("------- Carregando os dados para o mongodb ------------------")    
    print(f"Lendo o  arquivo: {arquivo} e convertendo para dict pandas...\n")
    data = df.to_dict(orient="records")
    db = client["SEBRAE"]
    col = db[arquivo]

    print("\nIniciando a gravação no mongodb...\n ")
    col.insert_many(data)
    print(f"{arquivo} gravado com sucesso!")
    print("\n------- fim  da carga dos dados para o mongodb ------------------\n")

# %%
def transfer_to_postgres(data, collection_name):
    print("------- Conectando com o PostgreSQL ------------------")     

    config = load_config()
    
    # Conectando ao PostgreSQL
    conn = psycopg2.connect(
        host=config["pg_host"],
        port=config["pg_port"],
        dbname=config["pg_db_name"],
        user=config["pg_user"],
        password=config["postgresql"]["pg_password"]
    )

    # Criando um cursor
    cur = conn.cursor()

    # Verificando se a tabela existe
    cur.execute(f"SELECT to_regclass('stg_rais.{collection_name}');")
    table_exists = cur.fetchone()[0]

    # Se a tabela não existir, criamos ela
    if not table_exists:
        print(f"A tabela {collection_name} não existe, criando...")
        
        # Obtendo os nomes das colunas da collection do MongoDB
        columns = data[0].keys()
        
        # Determinando o tipo de cada coluna
        column_types = []
        for column in columns:
            max_length = max(len(str(record[column])) for record in data)
            if isinstance(data[0][column], int):
                if max(record[column] for record in data) < 32767:  # smallint range
                    column_types.append(f"{column} smallint")
                elif max(record[column] for record in data) < 2147483647:  # int range
                    column_types.append(f"{column} int")
                else:
                    column_types.append(f"{column} bigint")
            else:
                column_types.append(f"{column} varchar({max_length})")
        
        # Criando a tabela no PostgreSQL com as mesmas colunas
        columns_query = ", ".join(column_types)
        create_table_query = f"CREATE TABLE stg_rais.{collection_name} ({columns_query});"
        cur.execute(create_table_query)

    # Inserindo os dados na tabela
    print("------- Transferindo os dados para o PostgreSQL ------------------")  
    for record in data:
        columns = ', '.join(record.keys())
        placeholders = ', '.join(['%s'] * len(record))
        insert_query = f"INSERT INTO stg_rais.{collection_name} ({columns}) VALUES ({placeholders})"
        cur.execute(insert_query, list(record.values()))

    # Commit das alterações e fechamento da conexão
    conn.commit()
    cur.close()
    conn.close()

    print(f"{collection_name} transferido com sucesso!")

# %% [markdown]
# ## **2.2 DEFININDO CAMINHO DA PLANILHA DO DICIONÁRIO, LENDO ELA E IMPRIMINDO LISTA COM AS ABAS EXISTENTES**

# %%
# Definindo caminho e imprimindo uma lista com todas as sheets da planilha
ds_owner = input('Insira seu nome e sobrenome (Ex: Marcilio Duarte)')
path = input('Insira o caminho do arquivo excel onde estão as dimensões/tabelas (dicionário): ')
xls = pd.ExcelFile(path)
sheets = xls.sheet_names[1:-1]
print(sheets)
# Out:
# ['dm_bairro_sp', 'dm_bairro_fortaleza', 'dm_bairro_rj', 'dm_cnae_2_classe', 'dm_cnae_1_classe', 'dm_distrito_sp', 'dm_ind_ativ_ano', 'dm_ind_cei_vinculado', 'dm_ind_pat', 'dm_ind_rais_negativa', 'dm_ind_simples', 'dm_id_municipio', 'dm_nat_jur', 'dm_regiao_adm_df', 'dm_cnae_2_subclasse', 'dm_tam_estab', 'dm_tipo_estab', 'dm_sigla_uf', 'dm_subsetor_ibge', 'dm_cep', 'dm_padrao_sebrae', 'dm_porte_sebrae', 'dm_setor_sebrae', 'dm_setor_ibge']

# %% [markdown]
# ## **2.3 RODANDO**

# %%
for i in sheets:
    df = pd.read_excel(path, sheet_name=i)
    df['curr_date'] = str(date.today())
    df['ds_owner'] = ds_owner
    for col in df.columns:
        df[col] = df[col].apply(lambda x: x.strip() if isinstance(x, str) else x)
    coll_name = str.upper('tb_rais_estab'+i[2:])
    upload_mongodb(df=df, arquivo=coll_name)
    # Suponha que df seja o seu DataFrame
    df = df.to_dict('records')
    transfer_to_postgres(data=df, collection_name=coll_name)
# Out:
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_BAIRRO_SP e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_BAIRRO_SP gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_BAIRRO_SP não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_BAIRRO_SP transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_BAIRRO_FORTALEZA e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_BAIRRO_FORTALEZA gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_BAIRRO_FORTALEZA não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_BAIRRO_FORTALEZA transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_BAIRRO_RJ e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_BAIRRO_RJ gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_BAIRRO_RJ não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_BAIRRO_RJ transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_CNAE_2_CLASSE e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_CNAE_2_CLASSE gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_CNAE_2_CLASSE não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_CNAE_2_CLASSE transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_CNAE_1_CLASSE e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_CNAE_1_CLASSE gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_CNAE_1_CLASSE não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_CNAE_1_CLASSE transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_DISTRITO_SP e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_DISTRITO_SP gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_DISTRITO_SP não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_DISTRITO_SP transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_IND_ATIV_ANO e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_IND_ATIV_ANO gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_IND_ATIV_ANO não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_IND_ATIV_ANO transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_IND_CEI_VINCULADO e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_IND_CEI_VINCULADO gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_IND_CEI_VINCULADO não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_IND_CEI_VINCULADO transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_IND_PAT e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_IND_PAT gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_IND_PAT não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_IND_PAT transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_IND_RAIS_NEGATIVA e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_IND_RAIS_NEGATIVA gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_IND_RAIS_NEGATIVA não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_IND_RAIS_NEGATIVA transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_IND_SIMPLES e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_IND_SIMPLES gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_IND_SIMPLES não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_IND_SIMPLES transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_ID_MUNICIPIO e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_ID_MUNICIPIO gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_ID_MUNICIPIO não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_ID_MUNICIPIO transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_NAT_JUR e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_NAT_JUR gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_NAT_JUR não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_NAT_JUR transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_REGIAO_ADM_DF e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_REGIAO_ADM_DF gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_REGIAO_ADM_DF não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_REGIAO_ADM_DF transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_CNAE_2_SUBCLASSE e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_CNAE_2_SUBCLASSE gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_CNAE_2_SUBCLASSE não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_CNAE_2_SUBCLASSE transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_TAM_ESTAB e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_TAM_ESTAB gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_TAM_ESTAB não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_TAM_ESTAB transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_TIPO_ESTAB e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_TIPO_ESTAB gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_TIPO_ESTAB não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_TIPO_ESTAB transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_SIGLA_UF e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_SIGLA_UF gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_SIGLA_UF não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_SIGLA_UF transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_SUBSETOR_IBGE e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_SUBSETOR_IBGE gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_SUBSETOR_IBGE não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_SUBSETOR_IBGE transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_PADRAO_SEBRAE e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_PADRAO_SEBRAE gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_PADRAO_SEBRAE não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_PADRAO_SEBRAE transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_PORTE_SEBRAE e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_PORTE_SEBRAE gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_PORTE_SEBRAE não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_PORTE_SEBRAE transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_SETOR_SEBRAE e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_SETOR_SEBRAE gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_SETOR_SEBRAE não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_SETOR_SEBRAE transferido com sucesso!
# ------- Conectando com o mongodb ------------------
# ['SEBRAE']
# ------- Carregando os dados para o mongodb ------------------
# Lendo o  arquivo: TB_RAIS_ESTAB_SETOR_IBGE e convertendo para dict pandas...
#
#
# Iniciando a gravação no mongodb...
#
# TB_RAIS_ESTAB_SETOR_IBGE gravado com sucesso!
#
# ------- fim  da carga dos dados para o mongodb ------------------
#
# ------- Conectando com o PostgreSQL ------------------
# A tabela TB_RAIS_ESTAB_SETOR_IBGE não existe, criando...
# ------- Transferindo os dados para o PostgreSQL ------------------
# TB_RAIS_ESTAB_SETOR_IBGE transferido com sucesso!
